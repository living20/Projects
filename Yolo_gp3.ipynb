# %% [markdown]
# <a href="https://colab.research.google.com/github/RoyDibs/Rebars-and-debris-Classiffication/blob/master/Yolo_gp3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip dataset.zip
# Out:
# Archive:  dataset.zip
#    creating: dataset/
#    creating: dataset/train/
#    creating: dataset/train/debris/
#   inflating: dataset/train/debris/1.png
#   inflating: dataset/train/debris/10.png
#   inflating: dataset/train/debris/100.png
#   inflating: dataset/train/debris/101.png
#   inflating: dataset/train/debris/103.png
#   inflating: dataset/train/debris/104.png
#   inflating: dataset/train/debris/105.png
#   inflating: dataset/train/debris/106.png
#   inflating: dataset/train/debris/107.png
#   inflating: dataset/train/debris/108.png
#   inflating: dataset/train/debris/109.png
#   inflating: dataset/train/debris/11.png
#   inflating: dataset/train/debris/110.png
#   inflating: dataset/train/debris/111.png
#   inflating: dataset/train/debris/112.png
#   inflating: dataset/train/debris/113.png
#   inflating: dataset/train/debris/114.png
#   inflating: dataset/train/debris/115.png
#   inflating: dataset/train/debris/116.png
#   inflating: dataset/train/debris/117.png
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
print(torch.cuda.current_device())

torch.cuda.get_device_name(0)
# Out:
# 0
# 'Tesla T4'

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15365, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 15365 (delta 1), reused 2 (delta 0), pack-reused 15355
# Receiving objects: 100% (15365/15365), 14.36 MiB | 26.03 MiB/s, done.
# Resolving deltas: 100% (10501/10501), done.

# %%
# %cd yolov5
# %pip install -r requirements.txt
# Out:
# /content/yolov5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 12.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 10.7 MB/s eta 0:00:00
# ...

# %%
# Train YOLOv5s Classification on Imagenette160 for 3 epochs
# !python classify/train.py --model yolov5s-cls.pt --data /content/dataset --epochs 15 --img 224 --cache
# Out:
# classify/train: model=yolov5s-cls.pt, data=/content/dataset, epochs=15, batch_size=64, imgsz=224, nosave=False, cache=ram, device=, workers=8, project=runs/train-cls, name=exp, exist_ok=False, pretrained=True, optimizer=Adam, lr0=0.001, decay=5e-05, label_smoothing=0.1, cutoff=None, dropout=None, verbose=False, seed=0, local_rank=-1
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-133-gcca5e21 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# TensorBoard: Start with 'tensorboard --logdir runs/train-cls', view at http://localhost:6006/
# 2023-04-01 16:59:41.624225: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python classify/predict.py --weights /content/yolov5/runs/train-cls/exp/weights/best.pt --img 224 --source /content/test_dataset  --name exp_images
# Out:
# classify/predict: weights=['/content/yolov5/runs/train-cls/exp/weights/best.pt'], source=/content/test_dataset, data=data/coco128.yaml, imgsz=[224, 224], device=, view_img=False, save_txt=False, nosave=False, augment=False, visualize=False, update=False, project=runs/predict-cls, name=exp_images, exist_ok=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-133-gcca5e21 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 117 layers, 4169250 parameters, 0 gradients, 10.4 GFLOPs
# ...
# image 1/10 /content/test_dataset/0.png: 224x224 rebars 0.96, debris 0.04, 6.2ms
# image 2/10 /content/test_dataset/111.png: 224x224 debris 1.00, rebars 0.00, 5.8ms
# image 3/10 /content/test_dataset/116.png: 224x224 debris 1.00, rebars 0.00, 5.1ms
# image 4/10 /content/test_dataset/124.png: 224x224 debris 0.99, rebars 0.01, 5.6ms
# image 5/10 /content/test_dataset/2.png: 224x224 rebars 0.57, debris 0.43, 5.2ms
# ...

# %%
# !zip -r /content/yolov5.zip /content/yolov5
# Out:
#   adding: content/yolov5/ (stored 0%)
#   adding: content/yolov5/runs/ (stored 0%)
#   adding: content/yolov5/runs/train-cls/ (stored 0%)
#   adding: content/yolov5/runs/train-cls/exp/ (stored 0%)
#   adding: content/yolov5/runs/train-cls/exp/events.out.tfevents.1680194578.edb9d51d0897.1250.0 (deflated 11%)
#   adding: content/yolov5/runs/train-cls/exp/train_images.jpg (deflated 4%)
#   adding: content/yolov5/runs/train-cls/exp/weights/ (stored 0%)
#   adding: content/yolov5/runs/train-cls/exp/weights/last.pt (deflated 8%)
#   adding: content/yolov5/runs/train-cls/exp/weights/best.pt (deflated 8%)
#   adding: content/yolov5/runs/train-cls/exp/opt.yaml (deflated 32%)
#   adding: content/yolov5/runs/train-cls/exp/results.csv (deflated 79%)
#   adding: content/yolov5/runs/train-cls/exp/test_images.jpg (deflated 5%)
#   adding: content/yolov5/runs/train-cls/exp2/ (stored 0%)
#   adding: content/yolov5/runs/train-cls/exp2/train_images.jpg (deflated 4%)
# ...
